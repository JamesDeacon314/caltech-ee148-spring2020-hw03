# %%
import matplotlib.pyplot as plt

training_fractions = [0.0625, 0.125, 0.25, 0.50, 0.85, 0.99]
training_accuracy = [0.9459, 0.9598, 0.9684, 0.9761, 0.9794, 0.9767]
testing_accuracy = [0.9581, 0.9679, 0.9760, 0.9827, 0.9851, 0.9844]

fig = plt.figure()
plt.loglog(training_fractions, training_accuracy,label='training acc')
plt.loglog(training_fractions, testing_accuracy, label='testing acc')
plt.title('MNIST Dataset Model Accuracy')
plt.xlabel('Log plot of Fraction of training data used to train')
plt.ylabel('Log plot of Accuracy')
plt.legend()
plt.ylim(0.949, 1.001)
fig.savefig("accuracy.png")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img00=mpimg.imread('Figure_62.png')
img01=mpimg.imread('Figure_1003.png')
img02=mpimg.imread('Figure_2018.png')
img10=mpimg.imread('Figure_3005.png')
img11=mpimg.imread('Figure_4007.png')
img12=mpimg.imread('Figure_5288.png')
img20=mpimg.imread('Figure_6065.png')
img21=mpimg.imread('Figure_7432.png')
img22=mpimg.imread('Figure_9905.png')

f, axarr = plt.subplots(3,3)
axarr[0,0].imshow(img00)
axarr[0,1].imshow(img01)
axarr[0,2].imshow(img02)
axarr[1,0].imshow(img10)
axarr[1,1].imshow(img11)
axarr[1,2].imshow(img12)
axarr[2,0].imshow(img20)
axarr[2,1].imshow(img21)
axarr[2,2].imshow(img22)
f.suptitle("9 Examples of Missclassified Numbers")

plt.show()
f.savefig("mistakes.png")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img00=mpimg.imread('kernel_0.jpg')
img01=mpimg.imread('kernel_1.jpg')
img10=mpimg.imread('kernel_2.jpg')
img11=mpimg.imread('kernel_3.jpg')

f, axarr = plt.subplots(2,2)
axarr[0,0].imshow(img00)
axarr[0,1].imshow(img01)
axarr[1,0].imshow(img10)
axarr[1,1].imshow(img11)

axarr[0,0].title.set_text("Channel 0")
axarr[0,1].title.set_text("Channel 1")
axarr[1,0].title.set_text("Channel 2")
axarr[1,1].title.set_text("Channel 3")
f.suptitle("4 Kernels From First Layer")

plt.show()
f.savefig("kernels.png")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('confusion_matrix.jpg')

fig = plt.figure(1)
plt.imshow(img)
plt.xlabel("Actual Label")
plt.ylabel("Predicted Label")
plt.title("MNIST Confusion Matrix")
plt.show()
fig.savefig("confusion_matrix.png")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img00=mpimg.imread('sim_0_1.png')
img01=mpimg.imread('sim_0_2.png')
img02=mpimg.imread('sim_0_3.png')
img03=mpimg.imread('sim_0_4.png')
img04=mpimg.imread('sim_0_5.png')
img05=mpimg.imread('sim_0_6.png')
img06=mpimg.imread('sim_0_7.png')
img07=mpimg.imread('sim_0_8.png')

img10=mpimg.imread('sim_1_1.png')
img11=mpimg.imread('sim_1_2.png')
img12=mpimg.imread('sim_1_3.png')
img13=mpimg.imread('sim_1_4.png')
img14=mpimg.imread('sim_1_5.png')
img15=mpimg.imread('sim_1_6.png')
img16=mpimg.imread('sim_1_7.png')
img17=mpimg.imread('sim_1_8.png')

img20=mpimg.imread('sim_2_1.png')
img21=mpimg.imread('sim_2_2.png')
img22=mpimg.imread('sim_2_3.png')
img23=mpimg.imread('sim_2_4.png')
img24=mpimg.imread('sim_2_5.png')
img25=mpimg.imread('sim_2_6.png')
img26=mpimg.imread('sim_2_7.png')
img27=mpimg.imread('sim_2_8.png')

f, axarr = plt.subplots(3,8)
axarr[0,0].imshow(img00)
axarr[0,1].imshow(img01)
axarr[0,2].imshow(img02)
axarr[0,3].imshow(img03)
axarr[0,4].imshow(img04)
axarr[0,5].imshow(img05)
axarr[0,6].imshow(img06)
axarr[0,7].imshow(img07)

axarr[1,0].imshow(img10)
axarr[1,1].imshow(img11)
axarr[1,2].imshow(img12)
axarr[1,3].imshow(img13)
axarr[1,4].imshow(img14)
axarr[1,5].imshow(img15)
axarr[1,6].imshow(img16)
axarr[1,7].imshow(img17)

axarr[2,0].imshow(img20)
axarr[2,1].imshow(img21)
axarr[2,2].imshow(img22)
axarr[2,3].imshow(img23)
axarr[2,4].imshow(img24)
axarr[2,5].imshow(img25)
axarr[2,6].imshow(img26)
axarr[2,7].imshow(img27)

f.suptitle("Most Similar Images")

f.text(0.5, 0.04, 'Images in Decreasing Euclidean Distance Left to Right', ha='center')
f.text(0.04, 0.5, 'Different Comparison Images', va='center', rotation='vertical')

plt.show()
f.savefig("similarity.png")
